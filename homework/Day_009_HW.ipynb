# %% [markdown]
# 作業目標:<br>
# 1.讀取各種檔案格式<br>
# 2.輸出各種檔案格式<br>

# %% [markdown]
# 作業重點:<br>
# 1.不同檔案讀取方式皆不同，須了解檔案格式中的邏輯，例如:csv是以逗號分隔<br>
# 2.讀取、輸出檔案的程式碼不同，須注意使用方式

# %% [markdown]
# 題目: <br>
# 讀取資料夾中boston.csv讀取其欄位CHAS、NOX、RM，輸出成.xlsx檔案

# %%
import pandas as pd

# %%
#讀取資料夾中boston.csv讀取其欄位CHAS、NOX、RM，輸出成.xlsx檔案
pd.read_csv('boston.csv', usecols=['CHAS', 'NOX', 'RM'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-bc71d25890e1> in <module>
#       1 #讀取資料夾中boston.csv讀取其欄位CHAS、NOX、RM，輸出成.xlsx檔案
# ----> 2 pd.read_csv('boston.csv', usecols=['CHAS', 'NOX', 'RM'])
#
# ...
